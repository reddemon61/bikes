# %% [markdown]
# # Toronto Postal Codes with GeoCoding

# %% [markdown]
# ### URL to site to scrape https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M,

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# %%
#codes=pd.read_clipboard(sep='\t')

# %% [markdown]
# Data was 'scraped' by highlighting the table and copying it using the Pandas read_clipboard function. Fast but not stable. Cell changes everytime it is run if something different is in the clipboard. Quickly copied the results to a csv file as a precaution, and use that file later.

# %%
codes=codes.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
codes.to_csv('CACodes.csv')

# %%
codes=pd.read_csv('CACodes.csv')

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(codes['Borough'].unique()),
        codes.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %%
llcode=pd.read_csv('Geospatial_Coordinates.csv')
code=pd.read_csv('CACodes.csv')

# %%
Tor_Codes = pd.merge(code,
                    llcode[['Postal Code', 'Latitude', 'Longitude']],
                    on='Postal Code', how='left')

del Tor_Codes['Unnamed: 0']

# %%
Tor_Codes.to_csv('Tor_Codes.csv')
toronto_DF=pd.read_csv('~/Desktop/Projects/Coursera_Capstone/Tor_Codes.csv')

# %%
Tor_Codes
# Out:
#      Unnamed: 0.1 Postal Code      Borough  \
# 0               1         M1B  Scarborough
# 1               2         M1C  Scarborough
# 2               3         M1E  Scarborough
# 3               4         M1G  Scarborough
# 4               5         M1H  Scarborough
# ..            ...         ...          ...
# 98            170         M9N         York
# 99            171         M9P    Etobicoke
# 100           172         M9R    Etobicoke
# 101           175         M9V    Etobicoke
# 102           176         M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# ...

# %%
map_toronto = folium.Map(location=[43.6534817, -79.3839347], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_DF['Latitude'], toronto_DF['Longitude'], toronto_DF['Borough'], toronto_DF['Neighborhood']):
    label = '{},{}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Toronto Neighbourhoods
